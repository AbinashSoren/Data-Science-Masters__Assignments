# %%
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# Note: Here Exception class refers to the base class for all the exceptions.

Exception BaseException is the base class for built in 
exceptions.It cannot be directly inherited for user-defined class,
Insead we use Exception class,which we inherit to raise
custom error.

#program enter valid name
class valid_name_exception(Exception):
    def __init__(self,msg):
        self.msg=msg

def check_name_validity(name):
    if type(name)==str and len(name)>=3 and False if any(x.isdigit() for x in name) else True:
        return True
    else:
        return False
try:
    name_=input('Enter first name')
    if check_name_validity(name_):
        print('Name entered is in the correct format')
    else:
        raise valid_name_exception('Please Enter the correct Name..and try again')
except valid_name_exception as vae:
    print(vae)
    print('An exception is caught')
else:
    print('Thank you for using are Program')
finally:
    print('End of Program')

# %%
# Q2. Write a python program to print Python Exception Hierarchy.
# import inspect module
import inspect
  
# our treeClass function
def treeClass(cls, ind = 0):
    
      # print name of the class
    print ('-' * ind, cls.__name__)
      
    # iterating through subclasses
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
  
print("Hierarchy for Built-in exceptions is : ")
  
# inspect.getmro() Return a tuple 
# of class  cls’s base classes.
  
# building a tree hierarchy
# print(inspect.getmro(BaseException))
# print('---')
inspect.getclasstree(inspect.getmro(BaseException))
  
# function call
treeClass(BaseException)

# %%
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

The ArithmeticError Exception is the base class for all errors
associated with arithmetic operation.

For Example:
--> ZeroDivisionError
This Exception is there to handle cases where the user tries
to divide a number by zer0.

Code:

try:
    10/0
except ArithmeticError as e:
    print('{} --> {}'.format(e,e.__class__))

--> OverflowError
This Exception is there to handle cases where the number has 
overflown from a certain range.

Code:

j=1.01 
try:
    for i in range(1,5000):
        j**=i
except ArithmeticError as e:
    print('{} --> {}'.format(e,e.__class__))

# %%
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

The LookupError exception in Python forms the base class for
all exceptions that are raised when the index is not found
in a sqequce or a key in a dictionary.

LookupError
-->IndexError

For Example:
x=[i for i in range(1,11)]
try:
    print(x[11])
except LookupError as e:
    print('{} --> {}'.format(e,e.__class__))
        
-->KeyError
For Example:
x={'Name':'Abinash','Age':'25','City':'Durgapur'}
try:
    print(x['Height'])
except LookupError as e:
    print('{} --> {}'.format(e,e.__class__))

# %%
# Q5. Explain ImportError. What is ModuleNotFoundError?

ImportError is raised when a module,or member of a module,cannot 
be imported
For Example:
try:
    from abc import acs
except ImportError as e:
    print('{} --> {}'.format(e,e.__class__))

    
ModuleNotFoundError is raised when the module imported is not found:
For Example:
try:
    import acs
except ImportError as e:
    print('{} --> {}'.format(e,e.__class__))

# %%
# Q6. List down some best practices for exception handling in python.

-->Write Descriptive Exception even though the name is long for Example: CheckValidAgeExcepion,UserDoesNotExist this allows other user to understand our code much more. 
-->Try to Catch Specific Exception.
-->Avoid Raising Generic Exception.
-->Always use Finally block deallocate the resources.
